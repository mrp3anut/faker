# %%
import faker_boun as fk
from seisgenlib import eqlib
import matplotlib.pyplot as plt

from random import choice
# %matplotlib inline

# %%
print(len(eqlib))
# Out:
# 7491

# %%
#zeta: 0.2 - 0.8
#sigma = scale
#fn = scale&shape 5-10
#T90 = 0.3
#eps = 0.36 - 0.44
#tn = 30 - 100
#params = {"zeta" : 0.3, "sigma" : 0.9,"fn" :5,"T90" : 0.3,"eps" : 0.4,"tn" : 30}

# %%
s = choice(eqlib)

print(s)
# Out:
# {'zeta': 0.30000000000000004, 'sigma': 0.8, 'fn': 6, 'T90': 0.3, 'eps': 0.39999999999999997, 'tn': 65}

# %%
a = fk.generate_noise_and_eq(100, params =s) #params argument is optional.

# %%
plt.figure(figsize=(40,20))
plt.plot(a)
plt.show()

# %%
b = fk.generate_noise(100, noise_type='perlin')

# %%
plt.figure(figsize=(40,20))
plt.plot(b)
plt.show()

# %%
c = fk.generate_eq(100)

# %%
plt.figure(figsize=(40,20))
plt.plot(c)
plt.show()
