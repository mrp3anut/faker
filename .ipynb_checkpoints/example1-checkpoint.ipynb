# %%
import faker_boun as fk
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-d377536b3fee> in <module>
# ----> 1 import faker_boun as fk
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ~\Desktop\faker_boun\faker_boun.py in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 from noise import pnoise1
#       4 import matplotlib.pyplot as plt
#       5
#
# ~\.conda\envs\faker\lib\site-packages\pandas\__init__.py in <module>
#     191 # GH 27101
#     192 # TODO: remove Panel compat in 1.0
# --> 193 if pandas.compat.PY37:
#     194
#     195     def __getattr__(name):
#
# AttributeError: module 'pandas' has no attribute 'compat'

# %%
a = fk.generate_noise_and_eq(100, scale = 100)

# %%
plt.figure(figsize=(40,20))
plt.plot(a)
plt.show()

# %%
b = fk.generate_noise(100, noise_type='perlin')

# %%
plt.figure(figsize=(40,20))
plt.plot(b)
plt.show()

# %%
c = fk.generate_eq(100)

# %%
plt.figure(figsize=(40,20))
plt.plot(c)
plt.show()
